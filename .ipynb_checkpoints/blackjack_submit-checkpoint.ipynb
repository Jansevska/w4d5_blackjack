# %%
import random

class Card:
    def __init__(self):
        self.card_categories = ['Hearts', 'Diamonds', 'Clubs', 'Spades'] 
        self.cards_list = ['Ace', '2', '3', '4', '5', '6', '7', '8', '9', '10', 'Jack', 'Queen', 'King'] 
        self.deck = []
  
    def get_card_value(self, card): 
        if card[0] in ['Jack', 'Queen', 'King']: 
            return 10
        elif card[0] == 'Ace': 
            return 11
        else: 
            return int(card[0])
        
    def create_deck(self):
        self.deck = [(card, category) for category in card_categories for card in cards_list]
        random.shuffle(self.deck)
               
    def player_cards(self):
        new_card = self.deck.pop()
        return new_card
    
    def dealer_cards(self):
        new_card = self.deck.pop()
        return new_card

        
class Game:
    def __init__(self):
        self.player_cards = []
        self.dealer_cards = []
        self.player_score = 0
        self.dealer_score = 0
        self.cards = cards
        
    def player(self):
        new_card = self.player_cards() 
        self.player_cards.append(new_card)
        return new_card
        
    def score(self):
        player_score = sum(card.get_card_value(card) for card in self.player_cards) 
        dealer_score = sum(card.get_card_value(card) for card in self.dealer_cards)
        
        if player_score > 21: 
            print("Dealer Has:", self.dealer_cards) 
            print("Dealer's Score:", self.dealer_score) 
            print("You Have:", self.player_cards) 
            print("Your Score:", self.player_score) 
            print("Dealer wins\n(Player Loss Because Player Score is exceeding 21)")

            while dealer_score < 17: 
                new_card = self.deck.pop() 
                self.dealer_cards.append(new_card) 
                dealer_score += get_card_value(new_card) 

            print("Dealer Has:", self.dealer_cards) 
            print("Dealer's Score:", dealer_score) 
            print("\n")
            
            if self.player_cards == "Ace" + "10":
                print("________________________________\n")
                print("***     B l a c k j a c k    ***\n")
                print(" C O N G R A T U L A T I O N S ! ")
                print("________________________________")
            elif dealer_score > 21: 
                print("Dealer Has:", self.dealer_cards) 
                print("Dealer's Score:", dealer_score) 
                print("You Have:", self.player_cards) 
                print("Your Score:", player_score) 
                print("You Won!!!\n(Dealer Loss Because Dealer Score is exceeding 21)") 
            elif player_score > dealer_score: 
                print("Dealer Has:", self.dealer_cards) 
                print("Dealer's Score:", dealer_score) 
                print("You Have:", self.player_cards) 
                print("Your Score:", player_score) 
                print("You won!!!\n(Player Has High Score than Dealer)") 
            elif dealer_score > player_score: 
                print("Dealer Has:", self.dealer_cards) 
                print("Dealer's Score:", dealer_score) 
                print("You Have:", self.player_cards) 
                print("Your Score:", player_score) 
                print("Dealer wins\n(Dealer Has High Score than Player)") 
            else: 
                print("Dealer Has:", self.dealer_cards) 
                print("Dealer's Score:", dealer_score) 
                print("You Have:", self.player_cards) 
                print("Your Score:", player_score) 
                print("It's a tie.")
        
    def start(self):
        self.cards.create_deck(self.deck)
        for i in range(2):
            self.dealer.cards.append(self.deck.pop(), self.deck.pop())
            self.player.cards.append(self.deck.pop(), self.deck.pop())
            self.turn = self.player

        
    def finish(self):
        print("Bye Bye")
        

def main():
    card = Card()
    card.create_deck()
    game = Game()
    
    while True:
        print("________________________________________________________________\n")
        print("*  *  *  *  *     B  L  A  C  K  J  A  C  K        *  *  *  *  *")
        print("________________________________________________________________")
        print("\n")
        while True:
            choice = input("Enter 'play' to play or 'stop' to stop and quit playing > ")
            if choice == 'stop':
                game.finish()
                break
            elif choice == 'play':
                game.start()
                card.player_cards()
                game.score()
                while True:
                    choice = input('Enter "hit" to request another card or "stand" to play with what you have: ').lower()
                    if choice == "hit":
                        game.player()
                        game.score()
                    elif choice == "stand":
                        card.dealer_cards()
                        game.score()
                        break
                    else:
                        print("Invalid input. Please enter 'hit' or 'stand' > ")
            

main()
# Out:
# ________________________________________________________________
#
# *  *  *  *  *     B  L  A  C  K  J  A  C  K        *  *  *  *  *
# ________________________________________________________________
#
#
# Enter 'play' to play or 'stop' to stop and quit playing > play
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 132
#     128                     else:
#     129                         print("Invalid input. Please enter 'hit' or 'stand' > ")
# --> 132 main()
#
# Cell In[35], line 116, in main()
#     114     break
#     115 elif choice == 'play':
# --> 116     game.start()
#     117     card.player_cards()
#     118     game.score()
#
# Cell In[35], line 89, in Game.start(self)
#      88 def start(self):
# ---> 89     self.cards.create_deck(self.deck)
#      90     for i in range(2):
# ...
